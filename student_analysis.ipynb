# %% [markdown]
# # 🎓 Student Performance Analysis using Python
# This project explores factors affecting student academic performance using data analysis and visualization.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load dataset
data = pd.read_csv('student_performance.csv')
data.head()
# Out:
#    gender  study_hours parental_education  math_score  reading_score  \
# 0    male            4           bachelor          76             80
# 1  female            6        high school          89             90
# 2  female            5             master          84             88
# 3    male            3           bachelor          65             70
# 4  female            7                phd          92             94
#
#    writing_score
# 0             78
# 1             88
# 2             85
# 3             68
# 4             93

# %%
# Basic statistics
print(data.describe())

# Visualizing relationships
sns.pairplot(data, hue='gender')
plt.show()
# Out:
#        study_hours  math_score  reading_score  writing_score
# count     8.000000    8.000000       8.000000       8.000000
# mean      4.750000   77.625000      80.500000      78.750000
# std       1.669046   12.011156      11.538755      11.461114
# min       2.000000   58.000000      60.000000      59.000000
# 25%       3.750000   70.250000      73.750000      71.750000
# 50%       5.000000   80.000000      83.500000      81.500000
# 75%       6.000000   86.000000      88.500000      86.500000
# max       7.000000   92.000000      94.000000      93.000000

# %%
# Correlation heatmap
plt.figure(figsize=(8,6))
sns.heatmap(data.corr(numeric_only=True), annot=True, cmap='coolwarm')
plt.title('Correlation Heatmap of Student Performance')
plt.show()

# %% [markdown]
# ### 🔍 Insights:
# - Students studying more than 5 hours generally perform better.
# - Higher parental education often correlates with improved student outcomes.
# - Math, Reading, and Writing scores are positively correlated.
